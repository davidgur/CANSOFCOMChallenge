# %% [markdown]
# # Challenge: Machine Learning for Drone Identification
# ## David Gurevich

# %% [markdown]
# The identification of drones using sensors is an increasingly important problem in practice dueto the widespread availability of highly capable drones.  Radar is a long-range active sensor thatcan detect drones at longer ranges, as compared to optical sensors.  Therefore, it is of interest toinvestigate if radars can be used to identify drones.

# %%
import numpy as np
import pywt
import matplotlib.pyplot as plt

from scipy import signal, constants, fft
from sympy import *

# %% [markdown]
# ### 1: Implement Time-Domain Radar Return Signals from Drones

# %% [markdown]
# We begin by defining the function, $\phi(t)$. This function will take the following parameters:
#
# $L_1$ -- (`L_1`) distance of the blade roots from the centre of rotation
#
# $L_2$ -- (`L_2`) distance of the blade tips from the centre of rotation
#
# $N$   -- (`N`) number of blades
#
# $R$   -- (`R`) range of the centre of rotation
#
# $V_\text{rad}$ -- (`V_rad`) radial velocity of the center of rotation with respect to the radar
#
# $\theta$ -- (`theta`) angle between the plane of rotation and the line of sight from the radar to the center of rotation
#
# $f_c$ -- (`fc`) transmitted frequency
#
# $f_\text{rot}$ -- (`f_rot`) frequency of rotation
#
# $t$ -- (`t`) time (linspace in Python)
#
# We also define a scaling constant, $A$, that will remain 1 for now.

# %%
# Scaling constant
A = 1.0

def phi(L1, L2, N, R, V, theta, lmbda, f_rot, t):
    fc = constants.c / lmbda
    w_c = 2 * np.pi * fc
    w_r = 2 * np.pi * f_rot
    
    exp = lambda n : np.exp(1j * (w_c * t - (4*np.pi/lmbda) * (R + V*t + ((L1 + L2)/2) * np.cos(theta) * np.sin(w_r * t + 2*np.pi*n/N))))
    sinc = lambda n : np.sinc((4*np.pi/lmbda) * ((L2 - L1)/2) * np.cos(theta) * np.sin(w_r * t + 2 * np.pi * n / N))
    
    data = np.zeros(t.shape)
    for n in range (0, N):
        data += exp(n).real * sinc(n)
    
    return A * (L2 - L1) * data

# %% [markdown]
# Let's try this out on some "demo drone"

# %%
# Define Parameters
L_1 = 0.25
L_2 = 1
N = 4
R = 0
V_rad = 0
theta = 0
lmbda = 0.20
f_rot = 40
fs = 100000
dur = 0.05
t = np.linspace(0, dur, int(dur*fs))

data = phi(L_1, L_2, N, R, V_rad, theta, lmbda, f_rot, t)
#data = psi(t, lmbda, V_rad, L_1, L_2, theta, f_rot, N, 1)

plt.rcParams['figure.figsize'] = [8, 6]
plt.plot(t, data)
plt.xlabel("Time (s)")
plt.ylabel("Amplitude")
plt.title("$\phi(t)$")
plt.show()

f1, t1, Sxx1 = signal.stft(data, fs, nperseg=4, return_onesided=True)
plt.pcolormesh(t1, f1, np.abs(Sxx1), shading='gouraud')
plt.xlabel("Time (s)")
plt.ylabel("Frequency (Hz)")
plt.title("Short Window STFT of $\phi(t)$")
plt.show()

f2, t2, Sxx2 = signal.stft(data, fs, nperseg=256, return_onesided=True)
plt.pcolormesh(t2, f2, np.abs(Sxx2), shading='gouraud')
plt.xlabel("Time (s)")
plt.ylabel("Frequency (Hz)")
plt.title("Long Window STFT of $\phi(t)$")
plt.show()


coeffs, _ = pywt.cwt(data.real, range(1, 256), "morl")
print(data.shape)
print(coeffs.shape)
# Out:
# (5000,)
# (255, 5000)

# %% [markdown]
# ## 2: Simulate Radar Returns from Drones
#
# The received radar signals from a drone is given by $\phi(t) + \mathbf{n}$, where $\mathbf{n}$ is random noise modelled by the Gaussian distribution with variance $\sigma^2$. The signal-to-noise ratio (SNR) is defined as $\left(\frac{A_r^2}{\sigma^2}\right)$, and the SNR in decibels is given by $10\log_{10} \left(\frac{A^2}{\sigma^2}\right)$
#
# Here, I have chosen to model two hypothetical radars, one in X-Band (10 GHz), and the other in W-band (94 GHz)

# %%
x_band_radar = {}
x_band_radar['fc'] = 1 * 10**10
x_band_radar['lambda'] = constants.c / x_band_radar['fc']
x_band_radar['fs'] = int(1.5 * 10**4)

w_band_radar = {}
w_band_radar['fc'] = 9.4 * 10**10
w_band_radar['lambda'] = constants.c / w_band_radar['fc']
w_band_radar['fs'] = int(2.63 * 10**4)

# %% [markdown]
# Now, we write the function that generates our radar return

# %%
def radar_return(N, L2, f_rot, radar, SNR, t_offset):
    # N - number of blades
    # L2 - distance of blade tips from center of rotation
    # f_rot - frequency of rotation
    # radar - x_band_radar or w_band_radar
    # SNR - Signal/Noise ratio in dB
    # t_offset - offset for start of timeseries
    
    # (1) Generate timespace
    t = np.linspace(t_offset, 1 + t_offset, radar['fs'])
    
    # (2) Generate Signal
    signal = phi(0, L2, N, 10, 0, np.pi/6, constants.c / radar['fc'], f_rot, t)
    
    # (3) Generate Noise
    linear_snr = 10.0**(SNR/10.0)
    noise = np.random.normal(0, np.max(signal.real)/linear_snr, len(signal.real))
    
    # (5) Add noise to signal
    received = signal + noise
    
    return (t, received)

# %% [markdown]
# Let's test this out. Here is a sample radar return of a sample 4 propeller drone, from an X-Band radar, with an SNR of 5 dB

# %%
t, sample_return = radar_return(4, 0.1, 75, x_band_radar, 10, 0)

plt.plot(t, sample_return.real)
plt.xlabel("Time (s)")
plt.ylabel("Amplitude")
plt.title("Sample Return of 4 propeller drone from an X-band radar with SNR of 10 dB")
plt.show()

f1, t1, Sxx1 = signal.stft(sample_return.real, fs, return_onesided=True)
plt.pcolormesh(t1, f1, np.abs(Sxx1), shading='gouraud')
plt.xlabel("Time (s)")
plt.ylabel("Frequency (Hz)")
plt.title("STFT of $\phi(t)$")
plt.show()

# %% [markdown]
# Here it is with 5 dB SNR:

# %%
t, sample_return = radar_return(4, 0.1, 75, x_band_radar, 5, 0)

plt.plot(t, sample_return.real)
plt.xlabel("Time (s)")
plt.ylabel("Amplitude")
plt.title("Sample Return of 4 propeller drone from an X-band radar with SNR of 5 dB")
plt.show()

f1, t1, Sxx1 = signal.stft(sample_return.real, fs, return_onesided=True)
plt.pcolormesh(t1, f1, np.abs(Sxx1), shading='gouraud')
plt.xlabel("Time (s)")
plt.ylabel("Frequency (Hz)")
plt.title("Short Window STFT of $\phi(t)$")
plt.show()

# %% [markdown]
# ## 3: Prepare Data Sets for application of ML techniques
# Here, we will choose four different types of commercially available drones for simulation and verification, and we will generate simulated data sets for three different SNRs, such as 10, 5, and 0 dB, for both X-band and W-band radar.

# %% [markdown]
# First, we generate our drones:

# %%
drones = [{} for _ in range(4)]

drones[0]["N"] = 4
drones[0]["L2"] = 0.1
drones[0]["frot"] = 100

drones[1]["N"] = 1
drones[1]["L2"] = 0.1
drones[1]["frot"] = 180

drones[2]["N"] = 1
drones[2]["L2"] = 0.05
drones[2]["frot"] = 80

drones[3]["N"] = 6
drones[3]["L2"] = 0.12
drones[3]["frot"] = 100

# %% [markdown]
# We also will be testing the following SNRs: 10 dB, 5 dB, 0 dB

# %% [markdown]
# ### Dataset 1: X-Band, 10 dB SNR

# %%
def build_dataset_1(N):
    dataset_1 = np.array([[0, np.zeros(shape=(15000))] for _ in range(N * len(drones))], dtype='object')

    for i, drone in enumerate(drones):
        for j in range(N):
            time_offset = 10 * np.random.random_sample()
            
            dataset_1[j][0] = i
            dataset_1[j][1][:] = radar_return(drone["N"], 
                                              drone["L2"], 
                                              drone["frot"], 
                                              x_band_radar, 
                                              10, 
                                              time_offset)[1].real
    return dataset_1

# %% [markdown]
# ### Dataset 2: X-Band, 5 dB SNR

# %%
def build_dataset_2(N):
    dataset_2 = np.array([[0, np.zeros(shape=(15000))] for _ in range(N * len(drones))], dtype='object')

    for i, drone in enumerate(drones):
        for j in range(N):
            time_offset = 10 * np.random.random_sample()
            
            dataset_2[j][0] = i
            dataset_2[j][1][:] = radar_return(drone["N"], 
                                              drone["L2"], 
                                              drone["frot"], 
                                              x_band_radar, 
                                              5, 
                                              time_offset)[1].real
    return dataset_2

# %% [markdown]
# ### Dataset 3: X-Band 0 dB SNR

# %%
def build_dataset_3(N):
    dataset_3 = np.array([[0, np.zeros(shape=(15000))] for _ in range(N * len(drones))], dtype='object')

    for i, drone in enumerate(drones):
        for j in range(N):
            time_offset = 10 * np.random.random_sample()
            
            dataset_3[j][0] = i
            dataset_3[j][1][:] = radar_return(drone["N"], 
                                              drone["L2"], 
                                              drone["frot"], 
                                              x_band_radar, 
                                              0, 
                                              time_offset)[1].real
    return dataset_3

# %% [markdown]
# ### Dataset 4: W-Band 10 dB SNR

# %%
def build_dataset_4(N):
    dataset_4 = np.array([[0, np.zeros(shape=(15000))] for _ in range(N * len(drones))], dtype='object')

    for i, drone in enumerate(drones):
        for j in range(N):
            time_offset = 10 * np.random.random_sample()
            
            dataset_4[j][0] = i
            dataset_4[j][1][:] = radar_return(drone["N"], 
                                              drone["L2"], 
                                              drone["frot"], 
                                              w_band_radar, 
                                              10, 
                                              time_offset)[1].real[:15000]
    return dataset_4

# %% [markdown]
# ### Dataset 5: W-Band 5 dB SNR

# %%
def build_dataset_5(N):
    dataset_5 = np.array([[0, np.zeros(shape=(15000))] for _ in range(N * len(drones))], dtype='object')

    for i, drone in enumerate(drones):
        for j in range(N):
            time_offset = 10 * np.random.random_sample()
            
            dataset_5[j][0] = i
            dataset_5[j][1][:] = radar_return(drone["N"], 
                                              drone["L2"], 
                                              drone["frot"], 
                                              w_band_radar, 
                                              5, 
                                              time_offset)[1].real[:15000]
    return dataset_5

# %% [markdown]
# ### Dataset 6: W-Band 0 dB SNR

# %%
def build_dataset_6(N):
    dataset_6 = np.array([[0, np.zeros(shape=(15000))] for _ in range(N * len(drones))], dtype='object')

    for i, drone in enumerate(drones):
        for j in range(N):
            time_offset = 10 * np.random.random_sample()
            
            dataset_6[j][0] = i
            dataset_6[j][1][:] = radar_return(drone["N"], 
                                              drone["L2"], 
                                              drone["frot"], 
                                              w_band_radar, 
                                              0, 
                                              time_offset)[1].real[:15000]
    return dataset_6

# %% [markdown]
# ## 4: Apply Machine Learning Techniques to Identification of Drones
#
# In this section, we will construct a convolutional neural network (CNN) to identify drones.

# %% [markdown]
# First, we apply the continuous wavelet transform (CWT) to each point in the dataset, then, we split the data into testing data and training data

# %%
def build_train_test(dataset):
    np.random.shuffle(dataset)
    labels, signals = zip(*dataset)
    
    # Defining train and test data arrays
    train_size = int(0.8 * len(signals))
    test_size = len(signals) - train_size
    
    train_labels = labels[:train_size]
    test_labels = labels[train_size:]
    
    train_data_cwt = np.ndarray(shape=(train_size, 64, len(signals[0])))
    test_data_cwt  = np.ndarray(shape=(test_size, 64, len(signals[0])))
    
    # CWT params
    scales = range(64, 128)
    wavelet_name = 'morl'

    # Calculate CWT
    for i in range(train_size):
        signal = signals[i]
        coeff, _ = pywt.cwt(signal, scales, wavelet_name, 1)
        train_data_cwt[i, :, :] = coeff
        
    for i in range(train_size, train_size + test_size):
        signal = signals[i]
        coeff, _ = pywt.cwt(signal, scales, wavelet_name, 1)
        test_data_cwt[i - train_size, :, :] = coeff
    
    x_train = train_data_cwt
    y_train = train_labels
    
    x_test = test_data_cwt
    y_test = test_labels
    
    return x_train, y_train, x_test, y_test

# %% [markdown]
# Now that we are capable of building the data in the right format, we must now train a CNN.

# %%
import keras
from keras.layers import Dense, Flatten
from keras.layers import Conv1D, MaxPooling1D
from keras.models import Sequential
from keras.callbacks import History

def train_model(x_train, y_train, x_test, y_test):
    history = History()
    
    input_shape = (64, 15000)
    
    num_classes = 6
    batch_size = 16
    epochs = 10
    
    x_train = x_train.astype('float32')
    x_test = x_test.astype('float32')
    
    y_train = keras.utils.to_categorical(y_train, num_classes)
    y_test = keras.utils.to_categorical(y_test, num_classes)
    
    
    model = Sequential()
    model.add(Conv1D(32, kernel_size=5, strides=1,
                     activation='relu',
                     input_shape=input_shape))
    model.add(MaxPooling1D(pool_size=2, strides=2))
    model.add(Conv1D(64, 5, activation='relu'))
    model.add(MaxPooling1D(pool_size=2))
    model.add(Flatten())
    model.add(Dense(1000, activation='relu'))
    model.add(Dense(num_classes, activation='softmax'))
    
    
    """
    model = Sequential()
    model.add(Conv2D(32, 5, strides=1, activation='relu', input_shape=input_shape))
    model.add(Conv2D(64, 5, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))
    model.add(Conv2D(128, 5, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))
    model.add(Dense(1024, activation='relu'))
    model.add(Dense(num_classes, activation='softmax'))
    """
    
    model.compile(loss=keras.losses.categorical_crossentropy,
                 optimizer=keras.optimizers.Adam(),
                 metrics=['accuracy'])
    
    model.fit(x_train, y_train,
             batch_size=batch_size,
             epochs=epochs,
             verbose=1,
             validation_data=(x_test, y_test),
             callbacks=[history])
    
    train_score = model.evaluate(x_train, y_train, verbose=0)
    print(f"Train loss: {train_score[0]}, Train accuracy: {train_score[1]}")
    test_score = model.evaluate(x_test, y_test, verbose=0)
    print(f"Test loss: {test_score[0]}, Test accuracy: {test_score[1]}")
    
    return model

# %% [markdown]
# Now, we generate datasets and models.

# %%
dataset_count = 40

dataset_1 = build_dataset_1(dataset_count)
dataset_2 = build_dataset_2(dataset_count)
dataset_3 = build_dataset_3(dataset_count)
dataset_4 = build_dataset_4(dataset_count)
dataset_5 = build_dataset_5(dataset_count)
dataset_6 = build_dataset_6(dataset_count)

# %%
x_train1, y_train1, x_test1, y_test1 = build_train_test(dataset_1)
x_train2, y_train2, x_test2, y_test2 = build_train_test(dataset_2)
x_train3, y_train3, x_test3, y_test3 = build_train_test(dataset_3)
x_train4, y_train4, x_test4, y_test4 = build_train_test(dataset_4)
x_train5, y_train5, x_test5, y_test5 = build_train_test(dataset_5)
x_train6, y_train6, x_test6, y_test6 = build_train_test(dataset_6)

# %%
model1 = train_model(x_train1, y_train1, x_test1, y_test1)
model2 = train_model(x_train2, y_train2, x_test2, y_test2)
model3 = train_model(x_train3, y_train3, x_test3, y_test3)
model4 = train_model(x_train4, y_train4, x_test4, y_test4)
model5 = train_model(x_train5, y_train5, x_test5, y_test5)
model6 = train_model(x_train6, y_train6, x_test6, y_test6)
# Out:
# Epoch 1/10
# 8/8 [==============================] - 2s 199ms/step - loss: 1.4618 - accuracy: 0.4493 - val_loss: 1.1956 - val_accuracy: 1.0000
# Epoch 2/10
# 8/8 [==============================] - 1s 160ms/step - loss: 0.9176 - accuracy: 1.0000 - val_loss: 3.9720 - val_accuracy: 0.8750
# Epoch 3/10
# 8/8 [==============================] - 1s 168ms/step - loss: 0.8956 - accuracy: 0.9803 - val_loss: 0.2069 - val_accuracy: 1.0000
# Epoch 4/10
# 8/8 [==============================] - 1s 161ms/step - loss: 0.1985 - accuracy: 0.9973 - val_loss: 0.1162 - val_accuracy: 1.0000
# Epoch 5/10
# 8/8 [==============================] - 1s 160ms/step - loss: 0.1531 - accuracy: 1.0000 - val_loss: 0.2085 - val_accuracy: 1.0000
# Epoch 6/10
# 8/8 [==============================] - 1s 163ms/step - loss: 0.1525 - accuracy: 1.0000 - val_loss: 0.0933 - val_accuracy: 1.0000
# Epoch 7/10
# 8/8 [==============================] - 1s 160ms/step - loss: 0.0739 - accuracy: 1.0000 - val_loss: 0.0387 - val_accuracy: 1.0000
# Epoch 8/10
# 8/8 [==============================] - 1s 161ms/step - loss: 0.0268 - accuracy: 1.0000 - val_loss: 0.0198 - val_accuracy: 1.0000
# Epoch 9/10
# 8/8 [==============================] - 1s 162ms/step - loss: 0.0263 - accuracy: 1.0000 - val_loss: 0.0704 - val_accuracy: 1.0000
# Epoch 10/10
# 8/8 [==============================] - 1s 163ms/step - loss: 0.0750 - accuracy: 1.0000 - val_loss: 0.0484 - val_accuracy: 1.0000
# Train loss: 0.04598294198513031, Train accuracy: 1.0
# Test loss: 0.048403095453977585, Test accuracy: 1.0
# Epoch 1/10
# 8/8 [==============================] - 2s 180ms/step - loss: 1.4772 - accuracy: 0.5297 - val_loss: 1.2682 - val_accuracy: 1.0000
# Epoch 2/10
# 8/8 [==============================] - 1s 161ms/step - loss: 1.1307 - accuracy: 1.0000 - val_loss: 0.6878 - val_accuracy: 1.0000
# Epoch 3/10
# 8/8 [==============================] - 1s 163ms/step - loss: 0.5257 - accuracy: 0.9872 - val_loss: 0.3003 - val_accuracy: 1.0000
# Epoch 4/10
# 8/8 [==============================] - 1s 161ms/step - loss: 0.2181 - accuracy: 1.0000 - val_loss: 0.0817 - val_accuracy: 1.0000
# Epoch 5/10
# 8/8 [==============================] - 1s 158ms/step - loss: 0.2878 - accuracy: 0.9947 - val_loss: 0.0666 - val_accuracy: 1.0000
# Epoch 6/10
# 8/8 [==============================] - 1s 172ms/step - loss: 0.0859 - accuracy: 1.0000 - val_loss: 0.1375 - val_accuracy: 1.0000
# Epoch 7/10
# 8/8 [==============================] - 1s 168ms/step - loss: 0.1117 - accuracy: 1.0000 - val_loss: 0.0603 - val_accuracy: 1.0000
# Epoch 8/10
# 8/8 [==============================] - 1s 172ms/step - loss: 0.0523 - accuracy: 1.0000 - val_loss: 0.0332 - val_accuracy: 1.0000
# Epoch 9/10
# 8/8 [==============================] - 1s 172ms/step - loss: 0.0290 - accuracy: 1.0000 - val_loss: 0.0190 - val_accuracy: 1.0000
# Epoch 10/10
# 8/8 [==============================] - 1s 171ms/step - loss: 0.0159 - accuracy: 1.0000 - val_loss: 0.0116 - val_accuracy: 1.0000
# Train loss: 0.011063206940889359, Train accuracy: 1.0
# Test loss: 0.011645480990409851, Test accuracy: 1.0
# Epoch 1/10
# 8/8 [==============================] - 2s 203ms/step - loss: 1.4801 - accuracy: 0.5947 - val_loss: 1.0929 - val_accuracy: 1.0000
# Epoch 2/10
# 8/8 [==============================] - 1s 166ms/step - loss: 1.0487 - accuracy: 0.9983 - val_loss: 0.5334 - val_accuracy: 1.0000
# Epoch 3/10
# 8/8 [==============================] - 1s 174ms/step - loss: 0.5201 - accuracy: 1.0000 - val_loss: 0.2849 - val_accuracy: 1.0000
# Epoch 4/10
# 8/8 [==============================] - 1s 172ms/step - loss: 0.2635 - accuracy: 1.0000 - val_loss: 1.5130 - val_accuracy: 0.9688
# Epoch 5/10
# 8/8 [==============================] - 1s 161ms/step - loss: 0.2088 - accuracy: 0.9872 - val_loss: 0.2780 - val_accuracy: 1.0000
# Epoch 6/10
# 8/8 [==============================] - 1s 164ms/step - loss: 0.3049 - accuracy: 1.0000 - val_loss: 0.2049 - val_accuracy: 1.0000
# Epoch 7/10
# 8/8 [==============================] - 1s 161ms/step - loss: 0.2007 - accuracy: 1.0000 - val_loss: 0.1321 - val_accuracy: 1.0000
# Epoch 8/10
# 8/8 [==============================] - 1s 166ms/step - loss: 0.1331 - accuracy: 1.0000 - val_loss: 0.0815 - val_accuracy: 1.0000
# Epoch 9/10
# 8/8 [==============================] - 1s 155ms/step - loss: 0.0842 - accuracy: 1.0000 - val_loss: 0.0464 - val_accuracy: 1.0000
# Epoch 10/10
# 8/8 [==============================] - 1s 162ms/step - loss: 0.0447 - accuracy: 1.0000 - val_loss: 0.0251 - val_accuracy: 1.0000
# Train loss: 0.027958717197179794, Train accuracy: 1.0
# Test loss: 0.025105787441134453, Test accuracy: 1.0
# Epoch 1/10
# 8/8 [==============================] - 2s 209ms/step - loss: 1.5786 - accuracy: 0.4276 - val_loss: 1.0488 - val_accuracy: 0.3125
# Epoch 2/10
# 8/8 [==============================] - 1s 165ms/step - loss: 1.0524 - accuracy: 0.4768 - val_loss: 0.3533 - val_accuracy: 1.0000
# Epoch 3/10
# 8/8 [==============================] - 1s 165ms/step - loss: 0.4312 - accuracy: 1.0000 - val_loss: 0.3608 - val_accuracy: 1.0000
# Epoch 4/10
# 8/8 [==============================] - 1s 171ms/step - loss: 0.3195 - accuracy: 1.0000 - val_loss: 0.1213 - val_accuracy: 1.0000
# Epoch 5/10
# 8/8 [==============================] - 1s 166ms/step - loss: 0.1129 - accuracy: 1.0000 - val_loss: 0.0569 - val_accuracy: 1.0000
# Epoch 6/10
# 8/8 [==============================] - 1s 166ms/step - loss: 0.0509 - accuracy: 1.0000 - val_loss: 0.0246 - val_accuracy: 1.0000
# Epoch 7/10
# 8/8 [==============================] - 1s 167ms/step - loss: 0.0239 - accuracy: 1.0000 - val_loss: 0.2497 - val_accuracy: 0.9688
# Epoch 8/10
# 8/8 [==============================] - 1s 170ms/step - loss: 0.0098 - accuracy: 1.0000 - val_loss: 0.4822 - val_accuracy: 0.9688
# Epoch 9/10
# 8/8 [==============================] - 1s 171ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.5942 - val_accuracy: 0.9688
# Epoch 10/10
# 8/8 [==============================] - 1s 163ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.6352 - val_accuracy: 0.9688
# Train loss: 0.0023752597626298666, Train accuracy: 1.0
# Test loss: 0.6352436542510986, Test accuracy: 0.96875
# Epoch 1/10
# 8/8 [==============================] - 2s 211ms/step - loss: 1.5534 - accuracy: 0.3877 - val_loss: 1.4005 - val_accuracy: 0.1562
# Epoch 2/10
# 8/8 [==============================] - 1s 166ms/step - loss: 1.0981 - accuracy: 0.4032 - val_loss: 0.9017 - val_accuracy: 1.0000
# Epoch 3/10
# 8/8 [==============================] - 1s 165ms/step - loss: 0.6374 - accuracy: 0.9945 - val_loss: 0.3018 - val_accuracy: 1.0000
# Epoch 4/10
# 8/8 [==============================] - 1s 169ms/step - loss: 0.3154 - accuracy: 1.0000 - val_loss: 0.4487 - val_accuracy: 1.0000
# Epoch 5/10
# 8/8 [==============================] - 1s 165ms/step - loss: 0.3323 - accuracy: 1.0000 - val_loss: 0.2498 - val_accuracy: 1.0000
# Epoch 6/10
# 8/8 [==============================] - 1s 167ms/step - loss: 0.1853 - accuracy: 1.0000 - val_loss: 0.1633 - val_accuracy: 1.0000
# Epoch 7/10
# 8/8 [==============================] - 1s 166ms/step - loss: 0.1245 - accuracy: 1.0000 - val_loss: 0.1015 - val_accuracy: 1.0000
# Epoch 8/10
# 8/8 [==============================] - 1s 166ms/step - loss: 0.0692 - accuracy: 1.0000 - val_loss: 0.0576 - val_accuracy: 1.0000
# Epoch 9/10
# 8/8 [==============================] - 1s 163ms/step - loss: 0.0437 - accuracy: 1.0000 - val_loss: 0.0318 - val_accuracy: 1.0000
# Epoch 10/10
# 8/8 [==============================] - 1s 163ms/step - loss: 0.0237 - accuracy: 1.0000 - val_loss: 0.0185 - val_accuracy: 1.0000
# Train loss: 0.015968499705195427, Train accuracy: 1.0
# Test loss: 0.018544062972068787, Test accuracy: 1.0
# Epoch 1/10
# 8/8 [==============================] - 2s 188ms/step - loss: 1.5263 - accuracy: 0.5586 - val_loss: 1.1880 - val_accuracy: 1.0000
# Epoch 2/10
# 8/8 [==============================] - 1s 183ms/step - loss: 1.0708 - accuracy: 1.0000 - val_loss: 0.7689 - val_accuracy: 1.0000
# Epoch 3/10
# 8/8 [==============================] - 1s 164ms/step - loss: 0.7063 - accuracy: 0.9930 - val_loss: 0.3371 - val_accuracy: 1.0000
# Epoch 4/10
# 8/8 [==============================] - 1s 166ms/step - loss: 0.2907 - accuracy: 1.0000 - val_loss: 0.1429 - val_accuracy: 1.0000
# Epoch 5/10
# 8/8 [==============================] - 1s 164ms/step - loss: 0.6409 - accuracy: 0.9930 - val_loss: 0.2305 - val_accuracy: 1.0000
# Epoch 6/10
# 8/8 [==============================] - 1s 164ms/step - loss: 0.2827 - accuracy: 1.0000 - val_loss: 0.3495 - val_accuracy: 1.0000
# Epoch 7/10
# 8/8 [==============================] - 1s 166ms/step - loss: 0.3144 - accuracy: 1.0000 - val_loss: 0.1798 - val_accuracy: 1.0000
# Epoch 8/10
# 8/8 [==============================] - 1s 165ms/step - loss: 0.1633 - accuracy: 1.0000 - val_loss: 0.1292 - val_accuracy: 1.0000
# Epoch 9/10
# 8/8 [==============================] - 1s 164ms/step - loss: 0.1224 - accuracy: 1.0000 - val_loss: 0.0811 - val_accuracy: 1.0000
# Epoch 10/10
# 8/8 [==============================] - 1s 159ms/step - loss: 0.0739 - accuracy: 1.0000 - val_loss: 0.0453 - val_accuracy: 1.0000
# Train loss: 0.04775179922580719, Train accuracy: 1.0
# Test loss: 0.045290373265743256, Test accuracy: 1.0

# %% [markdown]
# Now we build confusion matrices:
